# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[25,36,86,45]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x_o=[0,3,4,5,4,3,0,-3,-4,-5,-4,-3,0]
y_o=[5,4,3,0,-3,-4,-5,-4,-3,0,3,4,5]
plt.plot(x_o,y_o)
x_m = [6, 6, 7, 8, 9]
y_m = [-5, 5, 0, 5, -5]
plt.plot(x_m, y_m)  
   
xk1 = [12, 12]
yk1 = [-5, 5]
xk2 = [12, 16]
yk2 = [0, 5]
xk3 = [12, 16]
yk3 = [0, -5]
plt.plot(xk3, yk3)  
plt.plot(xk1, yk1)    
plt.plot(xk2, yk2)    
x_a1 = [18, 20]
y_a1 = [-5, 5]


x_a2 = [22, 20]
y_a2 = [-5, 5]

x_a3 = [19, 21]
y_a3 = [0, 0]
plt.plot(x_a1, y_a1)  
plt.plot(x_a2, y_a2)  
plt.plot(x_a3, y_a3)  

plt.axis('equal')

xr1 = [24, 24]
yr1 = [-5, 5]


xr2 = [24, 25, 26, 25, 24]
yr2 = [5, 5, 3, 1, 1]


xr3 = [24, 27]
yr3 = [0, -5]

plt.plot(xr1, yr1) 
plt.plot(xr2, yr2)  
plt.plot(xr3, yr3)  

plt.axis('equal')
plt.show()
